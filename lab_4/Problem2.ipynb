# %% [markdown]
# ## Lab 4, Problem 2
#
# Tankerkönig has been collecting gas prices at all German gas stations for more than nine years. The entire
# dataset weighs approximately 81 GB divided into 4000 CSV files, each holding gas prices of a single day. To
# access the data, mount the nnds network storage using the mount /mnt/nnds command. Use the provided
# example scripts to visualize the evolution of E10 for either a selected month, OR an entire year, OR the full
# dataset.

# %% [markdown]
# Code to load every file, not recommended.

# %%
import matplotlib.pyplot as plt
from os import listdir
import pandas as pd

# mount folder from the network
# mount /mnt/share/nnds

# path = "/mnt/nnds/tankerkoenig-data/prices/"
# year = []
# months = []

# file_list_year = listdir(path)
# for years in file_list_year:
#     year.append(years)

# file_list_month = listdir(path+year[1]) # To lazy to do 12 months
# for month in file_list_month:
#     months.append(month)   


# df_list = []

# for diryear in file_list_year:
#     for dirmonth in file_list_month:
#         file_list = listdir(path+diryear+"/"+dirmonth)
#         for fname in file_list:
#                 df_list.append( pd.read_csv(path+diryear+"/"+dirmonth+"/"+fname) )

# %% [markdown]
# Only one month, from 2022 January 1rd "2022-01-01-prices.csv"

# %%
# mount folder from the network
# mount /mnt/nnds

path = "/mnt/nnds/tankerkoenig-data/prices/2022/01/2022-01-01-prices.csv"

df = pd.read_csv(path)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 295973 entries, 0 to 295972
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   date          295973 non-null  object
#  1   station_uuid  295973 non-null  object
#  2   diesel        295973 non-null  float64
#  3   e5            295973 non-null  float64
#  4   e10           295973 non-null  float64
#  5   dieselchange  295973 non-null  int64
#  6   e5change      295973 non-null  int64
#  7   e10change     295973 non-null  int64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 18.1+ MB

# %%
e10_data = df[['date','e10']]
e10_data.query("e10 > 0", inplace=True)
# Out:
# /tmp/ipykernel_15093/3919833387.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   e10_data.query("e10 > 0", inplace=True)

# %%
# Plotting the evolution of E10 prices
plt.figure(figsize=(20, 6))
plt.plot(e10_data['date'], e10_data['e10'])
plt.title('Evolution of E10 Prices')
plt.xlabel('Date')
plt.ylabel('Price (in Euros)')

plt.show()
